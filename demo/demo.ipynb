# %%
import sys
sys.path.append('../src/lib/')
import tree
from problem_pq import ProblemPQ
from strings_datagen import DataGen
from lmnn import LMNN

# %%
gen = DataGen(train_N=100, test_N=100)
X_train, y_train, X_test, y_test = gen.generate()

# %%
problem = ProblemPQ(X_train, y_train, X_test, y_test)
problem.compile()
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 4314.84it/s]
# 100%|██████████| 200/200 [00:00<00:00, 34762.79it/s]
# Encoding trees into profiles ...
# Encoding trees into tensors ...
# tensor dimension: 176
# params: 176
# trees: 200
# node labels: 4
# average size: 9.0

# %%
lmnn = LMNN(problem, k=3, target_k=3, lr=1e-2, wd=1e-4, epoch=400, b=50, margin=5.0, push_margin=5.0)
# Out:
# set targets and imposters
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
lmnn.learn()
# Out:
# BEFORE METRIC LEARNING
# Initial Test Accuracy:  0.81
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# UPDATE IMPOSTERS
# UPDATE IMPOSTERS
# UPDATE IMPOSTERS
# UPDATE IMPOSTERS
# UPDATE IMPOSTERS
# UPDATE IMPOSTERS
# UPDATE IMPOSTERS
#
# Test Accuracy:  0.95
