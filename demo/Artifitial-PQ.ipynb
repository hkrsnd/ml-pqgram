# %%
import sys
sys.path.append('../src/lib/')
import tree
from problem_pq import ProblemPQ
from strings_datagen import DataGen
from lmnn import LMNN

# %%
gen = DataGen(train_N=100, test_N=100)
X_train, y_train, X_test, y_test = gen.generate()

# %%
problem = ProblemPQ(X_train, y_train, X_test, y_test)
problem.compile()
# Out:
# ...
# 100%|██████████| 200/200 [00:00<00:00, 33960.60it/s]
# Encoding trees into profiles ...
# Encoding trees into tensors ...
# tensor dimension: 176
# params: 176
# trees: 200
# node labels: 4
# average size: 9.0

# %%
lmnn = LMNN(problem, k=3, target_k=3, lr=1e-2, wd=1e-3, epoch=800, b =100, margin=5.0, push_margin=5.0)
# Out:
# set targets and imposters
# A Jupyter Widget
# A Jupyter Widget

# %%
lmnn.learn()
# Out:
# BEFORE METRIC LEARNING
# test_acc (init):  0.82
# A Jupyter Widget
# test_acc:  0.88
# test_acc:  0.88
# test_acc:  0.91
# test_acc:  0.94
# test_acc:  0.93
# test_acc:  0.87
# test_acc:  0.86
#
# Test Accuracy:  0.94
